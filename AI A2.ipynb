# %% [markdown]
# ## MACHINE LEARNING DEFINITION
# Machine learning is a field of computer science that aims to teach computers how to learn and act without being explicitly programmed. More specifically, machine learning is an approach to data analysis that involves building and adapting models, which allow programs to "learn" through experience. Machine learning involves the construction of algorithms that adapt their models to improve their ability to make predictions.

# %% [markdown]
# # LOADING YOUR DATASET
#
# ## Dataset Definition
# A data set is a collection of data. In the case of tabular data, a data set corresponds to one or more database tables, where every column of a table represents a particular variable, and each row corresponds to a given record of the data set in question.
# ## How to load a Dataset in Python?
# One way of loading your dataset into Python is by the help of Pandas library. You have to import it and call it by using the function pd.read_csv. This command stores your dataset into a variable and whenever you call that variable it displays your dataset.

# %%
import pandas as pd

# %%
my_data=pd.read_csv("D:\Video_Games_Sales_as_at_22_Dec_2016.csv")

# %%
my_data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# # Exploring the Dataset:
# Video Games Sales & Game Ratings Data
# This dataset is about the Video Games Sales and their ratings. It has 16,719 rows and 16 columns which specify the:
# - Game Title
# - Release Platform
# - Release Year
# - Genre
# - Publisher
# - Sales in North America
# - Sales in Europe
# - Sales in Japan
# - Sales in Other Regions
# - Global sales
# - Critic Score
# - Critic Count
# - User Score
# - User Count
# - Developer Company
# - Age Rating

# %% [markdown]
# ### Use my_data.keys() function to findout all the keys you already have present in your Dataset

# %%
my_data.keys()
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %% [markdown]
# ### We can use variable_name.shape which is a built in function of Pandas that gives us a Tuple of the rows and columns in your Dataset

# %%
my_data.shape
# Out:
# (16719, 16)

# %% [markdown]
# ### dataVariable.info shows a list of all columns in your Dataset and each columns DataType as well

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %% [markdown]
# # Virtualizing your Dataset:
#
# Data can be virtualized into Charts and Graphs for a better understanding of what it shows.
# Different Graphs such as Global Sales of Different publishers, most common platforms,etc. can be made to show what our dataset is about.
# We use Metplotlib for these specific cases.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %% [markdown]
# ### This Graph shows us the how many games from each genre are made and which Genre is the most in-demand.

# %%
sns.set_theme(style="darkgrid")
sns.set(rc={'figure.figsize':(18,8.27)})
sns.countplot(x = 'Genre',data = my_data,palette = 'bwr')
plt.xlabel('Genre')
plt.ylabel('Titles Made')

plt.show()

# %% [markdown]
# ### The Graph below shows the number of titles that were made for each platform and which platform had the most.

# %%
sns.set(rc={'figure.figsize':(18,8.27)})
sns.countplot(x = 'Platform',data = my_data,palette = 'winter_r')
plt.xlabel('Platform')
plt.ylabel('Released Titles')
plt.show()

# %% [markdown]
# ### The graph below shows how many games were made of different Age Ratings.

# %%
sns.set(rc={'figure.figsize':(18,8.27)})
sns.countplot(x = 'Rating',data = my_data,palette = 'viridis')
plt.xlabel('Rating')
plt.ylabel('Titles Made')

plt.show()

# %% [markdown]
# # K-Means Algorithm

# %% [markdown]
# K-Mean is one of the most straightforward and well-known unsupervised learning strategies for clustering issues.
#
# The process uses a predetermined number of clusters that you have selected before you run the algorithm to classify a given data set in a straightforward and straightforward manner.
#
# You choose the number k, or the number of clusters, at random. Then, for each data point, the k-means algorithm will locate the closest cluster centre and allocate the data point that is closest to that cluster. The cluster centres will be updated once each data point has been assigned to a cluster.
#
# In other words, as the values of the cluster data points are averaged, new cluster centres will form.Until the majority of the data points remain in the same cluster, this process is repeated. The cluster membership ought to settle down.
#
# Because of the way the k-means algorithm operates, it is clear that the initial set of cluster centres that are abandoned can have a big impact on the clusters that are ultimately discovered.
#
# Of course, you can deal with this consequence however, you should absolutely look into getting your data ready for this purpose before you move on to creating a model for it.

# %% [markdown]
# # Preprocessing Data:
# Before modeling the data, it's a good idea to first prepare the data. This preparation step is called preprocessing of the data.
#
# In this we remove the data of the columns first. Data normalization is done in data preprocessing.

# %% [markdown]
# ### Count missing values in each row and column

# %%
my_data.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
my_data['Year_of_Release'] = my_data['Year_of_Release'].fillna(my_data['Year_of_Release'].mean())
my_data['Critic_Score'] = my_data['Critic_Score'].fillna(my_data['Critic_Score'].mean())
my_data['Critic_Count'] = my_data['Critic_Count'].fillna(my_data['Critic_Count'].mean())
my_data['User_Score'] = my_data['User_Score'].fillna(my_data['User_Score'].mean())
my_data['User_Count'] = my_data['User_Count'].fillna(my_data['User_Count'].mean())

# %%
my_data.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release       0
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score          0
# Critic_Count          0
# User_Score            0
# User_Count            0
# Developer          6623
# Rating             6769
# dtype: int64

# %% [markdown]
# ## Spliting data into train and test:
# Additionally, you must separate the data set into a training set and a test set so that you can subsequently evaluate the performance of your model.
#
# Test Dataset is used to assess the learnt or trained system.
#
# Train Dataset is used to train the system.
#
# The most popular splitting option is to use two thirds of your original data set as the training set and the remaining one third as the test set.

# %%
from sklearn.model_selection import train_test_split

# %%
predictors = my_data.drop('Genre', axis = 1)
target = my_data['Genre']
x_train, x_test, y_train, y_test= train_test_split(predictors,target, test_size = 0.25, random_state = 0)

# %%
x_train
# Out:
#                                                     Name Platform  \
# 4202                            Godzilla: Save the Earth      PS2
# 11473                           Diva Girls: Divas on Ice      Wii
# 16213                                 GoGo's Crazy Bones       DS
# 16481                        Sakura-Sou no Pet na Kanojo      PSV
# 12076  Crayon Shin-Chan: Densetsu o Yobu Omake no To ...      GBA
# ...                                                  ...      ...
# 9225                   Dead Island Definitive Collection      PS4
# 13123                      Monster 4x4: Masters of Metal       GC
# 9845                                   Sonic Adventure 2       DC
# 10799                      Ar tonelico: Melody of Elemia      PS2
# 2732                              Kane & Lynch: Dead Men      PS3
#
#        Year_of_Release               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 4202            2004.0                   Atari      0.23      0.18      0.00
# ...

# %%
x_test
# Out:
#                                                   Name Platform  \
# 7941                                      R-Type Final      PS2
# 4711                      The Terminator: Dawn of Fate      PS2
# 6171                       Dead to Rights: Retribution      PS3
# 766                              Skylanders SWAP Force      Wii
# 1963                                              DiRT      PS3
# ...                                                ...      ...
# 7682                                       Ratatouille      GBA
# 14882  Ookiku Furikabutte: Honto no Ace ni Nareru kamo       DS
# 5499                                 Battle Dodge Ball     SNES
# 10965                                      Return Fire       PS
# 6648                     Midway's Greatest Arcade Hits      GBA
#
#        Year_of_Release                Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 7941            2003.0                 Metro 3D      0.09      0.07      0.00
# ...

# %% [markdown]
# ## Clustering digits data:
# K-means clustering is a form of unsupervised learning used when you have unlabeled data.
#
# The purpose of this algorithm is to find groups in the data. where the number of groups is represented by the variable K.
#
# The algorithm iteratively assigns each data point to one of K groups based on the features provided.
#
# Data points are clustered based on feature similarity.
#
# Here are the results of the K-Means clustering algorithm:
#
# K cluster centroids that can be used to label new data training data labels (each data point is assigned to a single cluster) are formed organically.
#
# The "Choosing K" section below describes how to determine the number of groups.Each cluster centroid is a collection of feature values that define a group of results.
#
# By examining the weights of centroid features, we can qualitatively interpret which type of group each cluster represents. like in my case these clusters show number of deaths with allocated passanger ids which are then pointed as clusters on graph

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
import os

# %%
del data2
data2=data1.dropna(axis=0).reset_index(drop=True)
def doKmeans(X, nclust=2):
    model = KMeans(nclust)
    model.fit(X)
    clust_labels = model.predict(X)
    cent = model.cluster_centers_
    return (clust_labels, cent)

clust_labels, cent = doKmeans(data2, 5)
kmeans = pd.DataFrame(clust_labels)
data2.insert((data2.shape[1]),'kmeans',kmeans)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter(data2['Genre'],data2['Rating'],c=kmeans[0],s=50)
ax.set_title('K-Means Clustering')
ax.set_xlabel('Genre')
ax.set_ylabel('Rating')
plt.colorbar(scatter)

# %% [markdown]
# # Evaluation:
# Model evaluation allows you to evaluate model performance, compare different models and choose the best model for production.
# There are different methods using which you can evaluate your models depending on model type.
#
# I learnt alot of things from this assignment:
# - What a Dataset is.
# - How you can manipulate a Dataset and deduce useful information
# - How to illustrate this data in the form of figures and graphs for people to understand better.
# - How to differentiate raw data into train and test modules.
# - How to train a model with data.
#
# This assignment has been really informative for me and it has helped me realize how i can include my profession into things that i am passionate about and deduce useful results.

# %%
my_data.groupby(['Genre']).sum().plot(kind='pie', y='Global_Sales')
plt.show()
